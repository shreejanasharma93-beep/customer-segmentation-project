# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("customer_data.csv")
df.head()
# Out:
#    CustomerID  Age  Gender  Annual Income  Spending Score
# 0           1   19    Male             15              39
# 1           2   21    Male             15              81
# 2           3   20  Female             16               6
# 3           4   23  Female             16              77
# 4           5   31    Male             17              40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      10 non-null     int64
#  1   Age             10 non-null     int64
#  2   Gender          10 non-null     object
#  3   Annual Income   10 non-null     int64
#  4   Spending Score  10 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 532.0+ bytes

# %%
X = df[["Annual Income", "Spending Score"]]

# %%
kmeans = KMeans(n_clusters=3, random_state=0)

# %%
df["Cluster"] = kmeans.fit_predict(X)
# Out:
# C:\Users\SHREEJANA\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Annual Income  Spending Score  Cluster
# 0           1   19    Male             15              39        2
# 1           2   21    Male             15              81        0
# 2           3   20  Female             16               6        1
# 3           4   23  Female             16              77        0
# 4           5   31    Male             17              40        2

# %%
plt.scatter(df["Annual Income"], df["Spending Score"], c=df["Cluster"])

plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.title("Customer Segmentation")

plt.show()

# %%
df["Cluster"].value_counts()
# Out:
# Cluster
# 0    5
# 1    3
# 2    2
# Name: count, dtype: int64

# %%
df.to_csv("clustered_customers.csv", index=False)
